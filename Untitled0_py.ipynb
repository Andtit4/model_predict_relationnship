# %% [markdown]
# <a href="https://colab.research.google.com/github/Andtit4/model_predict_relationnship/blob/main/Untitled0_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, ys, epochs=500)
model.predict([10.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 287ms/step - loss: 16.7388
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 13.1939
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 10.4045
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2094
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.4819
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1223
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0522
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2098
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5466
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0245
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6132
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2892
# ...
